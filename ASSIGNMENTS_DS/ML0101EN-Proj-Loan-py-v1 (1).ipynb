# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align="center"><font size="5">Classification with Python</font></h1>

# %% [markdown]
# In this notebook we try to practice all the classification algorithms that we have learned in this course.
#
# We load a dataset using Pandas library, and apply the following algorithms, and find the best one for this specific dataset by accuracy evaluation methods.
#
# Let's first load required libraries:

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### About dataset

# %% [markdown]
# This dataset is about past loans. The **Loan_train.csv** data set includes details of 346 customers whose loan are already paid off or defaulted. It includes following fields:
#
# | Field          | Description                                                                           |
# | -------------- | ------------------------------------------------------------------------------------- |
# | Loan_status    | Whether a loan is paid off on in collection                                           |
# | Principal      | Basic principal loan amount at the                                                    |
# | Terms          | Origination terms which can be weekly (7 days), biweekly, and monthly payoff schedule |
# | Effective_date | When the loan got originated and took effects                                         |
# | Due_date       | Since it’s one-time payoff schedule, each loan has one single due date                |
# | Age            | Age of applicant                                                                      |
# | Education      | Education of applicant                                                                |
# | Gender         | The gender of applicant                                                               |

# %% [markdown]
# Let's download the dataset

# %%
# !wget -O loan_train.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/loan_train.csv
# Out:
# --2022-02-25 03:52:48--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/loan_train.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23101 (23K) [text/csv]
# Saving to: ‘loan_train.csv’
#
# loan_train.csv      100%[===================>]  22.56K  --.-KB/s    in 0s
#
# 2022-02-25 03:52:48 (245 MB/s) - ‘loan_train.csv’ saved [23101/23101]

# %% [markdown]
# ### Load Data From CSV File

# %%
df = pd.read_csv('loan_train.csv')
df.head()
dx=df[['loan_status']!='PAIDOFF']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4097/4046779621.py in <module>
#       1 df = pd.read_csv('loan_train.csv')
#       2 df.head()
# ----> 3 dx=df[['loan_status']!='PAIDOFF']
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: True

# %%
df.shape
# Out:
# (346, 10)

# %% [markdown]
# ### Convert to date time object

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Let’s see how many of each class is in our data set

# %%
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %% [markdown]
# 260 people have paid off the loan on time while 86 have gone into collection

# %% [markdown]
# Let's plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                               |failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - h5py -> python[version='<3']
#   - tenacity -> python[version='>=3.5,<3.6.0a0']
#
# Your python: python~=3.7
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with a past
# explicit spec that is not an explicit spec in this operation (pip):
#
#   - seaborn -> python[version='>=3.6'] -> pip
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libstdcxx-ng conflicts for:
# dbus -> expat[version='>=2.2.10,<3.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0']
# maven==3.6.0 -> openjdk -> libstdcxx-ng[version='>=7.5.0']
# jedi -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# typing_extensions -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# keras-applications -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# jupyter_client -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# leptonica -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# cycler -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# h5py -> hdf5[version='>=1.10.6,<1.10.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0|>=9.3.0']
# backcall -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# markupsafe -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# itsdangerous -> python[version='>=2.7,<2.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# tensorboard -> grpcio[version='>=1.24.3'] -> libstdcxx-ng[version='7.2.0.*|>=7.5.0|>=9.4.0']
# libllvm11 -> libstdcxx-ng[version='>=7.5.0|>=9.3.0']
# krb5 -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0']
# libarchive -> lz4-c[version='>=1.9.2,<1.10.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=9.3.0|>=7.5.0|>=7.2.0']
# pytz -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# idna -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# gmp -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# matplotlib-base -> kiwisolver -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=8.4.0']
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# backports.functools_lru_cache -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# graphviz==2.40.1 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# ninja -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng=7.2.0
# harfbuzz -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# mkl -> tbb=2021 -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.4.0']
# libvorbis -> libstdcxx-ng[version='>=9.3.0']
# scikit-image==0.17.2 -> matplotlib-base[version='>=2.0.0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.5.0|>=9.4.0|>=8.4.0']
# xlrd==1.2.0 -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# gst-plugins-base -> glib[version='>=2.53.6,<2.54.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=9.3.0']
# debugpy -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# six -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# nss -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.4.0']
# zstd -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0']
# grpcio -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng=7.2.0
# google-pasta -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# proj4==5.2.0 -> libstdcxx-ng[version='>=7.3.0|>=7.5.0']
# werkzeug -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# cryptography -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# geos -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.5.0|>=7.2.0']
# scikit-image==0.17.2 -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# nest-asyncio -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# termcolor -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# readline -> ncurses[version='>=6.1,<7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# tensorflow-estimator -> python[version='>=3'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0|>=5.4.0']
# ninja -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# jupyter_core -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pango -> cairo[version='>=1.14.12,<2.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0|>=9.3.0']
# cffi -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# munkres -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# libtiff -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libpq -> krb5[version='>=1.17.1,<1.18.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0']
# setuptools -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# ansi2html -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pytorch==1.5.0 -> libstdcxx-ng[version='>=7.3.0']
# libxkbcommon -> libstdcxx-ng[version='>=7.5.0']
# kiwisolver -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0|>=9.3.0']
# protobuf -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# grpcio -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pyyaml -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# zeromq -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0']
# ptyprocess -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# flask -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pillow -> libstdcxx-ng[version='>=8.4.0']
# py-opencv -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# gxx_linux-64==7.2.0 -> libstdcxx-ng==7.2.0=h24385c6_1
# keras-preprocessing -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tbb -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# gcc_linux-64 -> gcc_impl_linux-64=7.3.0 -> libstdcxx-ng[version='>=4.9|>=5.4.0|>=7.2.0|>=7.3.0|>=9.3.0|>=8.4.0|>=7.5.0']
# fontconfig -> icu[version='>=58.2,<59.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# binutils_impl_linux-64 -> libstdcxx-ng[version='>=7.3.0']
# pywavelets -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# flask-compress -> brotli-python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# numpy -> libopenblas[version='>=0.3.3,<1.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# icu -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=9.4.0']
# decorator -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# ffmpeg -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# tornado -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pyopenssl -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# qt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# mysql-libs -> zstd[version='>=1.4.9,<1.5.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# dash -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# imutils==0.5.4 -> matplotlib-base -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0|>=9.3.0']
# jupyter-dash==0.4.0 -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# glib-tools -> libstdcxx-ng[version='>=9.4.0']
# py-opencv -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=9.4.0|>=7.5.0']
# absl-py -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# jinja2 -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pygments -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# python_abi -> python=3.7 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.4.0']
# imageio -> pillow -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=8.4.0|>=7.5.0|>=9.4.0']
# toolz -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# nspr -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.4.0']
# glib -> pcre[version='>=8.44,<9.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# gcc_impl_linux-64 -> libstdcxx-ng[version='>=4.9|>=5.4.0|>=7.2.0|>=7.3.0|>=9.3.0|>=8.4.0|>=7.5.0']
# brotli -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# ncurses -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# gettext -> libffi[version='>=3.2.1,<4.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.5.0']
# libglib -> libstdcxx-ng[version='>=9.4.0']
# parso -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# brotlipy -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# basemap==1.2.0 -> libstdcxx-ng[version='>=7.3.0']
# tensorflow-base -> libstdcxx-ng[version='>=5.4.0|>=7.2.0|>=7.5.0']
# gst-plugins-base -> libstdcxx-ng[version='>=7.2.0|>=9.4.0|>=7.5.0|>=7.3.0']
# qt -> expat[version='>=2.2.6,<3.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.5.0|>=9.4.0']
# plotly -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tensorflow-base -> grpcio[version='>=1.16.1'] -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=9.4.0']
# zipp -> python[version='>=3.6'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# mysql-libs -> libstdcxx-ng[version='>=9.3.0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.5.0']
# networkx -> python[version='>=3.6'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0|>=9.3.0']
# ibm_db==3.0.4 -> libstdcxx-ng[version='>=9.3.0']
# cython -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# gstreamer -> glib[version='>=2.56.1,<2.57.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# traitlets -> python[version='>=3.7'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# hdf5 -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# libopencv -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pcre -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# pycocotools==2.0.2 -> cython -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0|>=9.3.0']
# openjpeg -> libtiff[version='>=4.0.9,<5.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libopencv -> libtiff[version='>=4.0.9,<5.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=9.4.0|>=9.3.0']
# pycparser -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# seaborn -> matplotlib[version='>=2.1.2'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# libwebp -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# glib -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# libxml2 -> icu[version='>=58.2,<59.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=9.4.0']
# unicodedata2 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# fonttools -> brotli -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# retrying -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tqdm==4.60.0 -> python[version='>=2.7'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# matplotlib-base -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.4.0|>=9.3.0']
# cloudpickle -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# cython -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng=7.2.0
# libedit -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# openjpeg -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.5.0|>=9.3.0']
# wrapt -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# partd -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# libclang -> libllvm11[version='>=11.1.0,<11.2.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# brotli-python -> libstdcxx-ng[version='>=7.3.0|>=9.4.0']
# charset-normalizer -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# ipykernel -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pandas -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# urllib3 -> python[version='<4.0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# gettext -> libstdcxx-ng[version='>=7.3.0']
# jasper -> freeglut[version='>=3.0.0,<4.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0']
# tesseract==4.1.1 -> openjpeg[version='>=2.3.1,<2.4.0a0'] -> libstdcxx-ng[version='>=9.3.0']
# entrypoints -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tensorflow==1.14.0 -> libstdcxx-ng[version='>=5.4.0']
# pytorch==1.5.0 -> ninja -> libstdcxx-ng[version='>=7.2.0|>=7.5.0|>=9.4.0']
# gnutls -> gmp[version='>=6.1.2'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0']
# imagecodecs-lite -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.4.0']
# graphviz==2.40.1 -> expat[version='>=2.2.5,<3.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.5.0|>=9.3.0|>=9.4.0']
# pip -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# libnghttp2 -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.4.0']
# gstreamer -> libstdcxx-ng[version='>=9.4.0']
# requests -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pickleshare -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# cairo -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# basemap==1.2.0 -> matplotlib-base[version='>=1.0.0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.5.0|>=9.4.0|>=9.3.0']
# libffi -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# certifi -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# libcurl -> krb5[version='>=1.17.1,<1.18.0a0'] -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# pyproj -> proj[version='>=6.2.1,<6.2.2.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# cudatoolkit -> libstdcxx-ng[version='>=7.3.0|>=9.3.0|>=9.4.0']
# argcomplete -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# nodejs==10.15.3 -> libstdcxx-ng[version='>=7.3.0']
# packaging -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# click -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# gnutls -> libstdcxx-ng[version='>=7.3.0|>=7.5.0']
# importlib-metadata -> python[version='>=3'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# gast -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# openh264 -> libstdcxx-ng[version='>=7.3.0|>=7.5.0']
# wcwidth -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tifffile -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tensorboard -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# sqlite -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pexpect -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# matplotlib-inline -> python[version='>=3.6'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tesseract==4.1.1 -> libstdcxx-ng[version='>=7.3.0']
# pyparsing -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# astor -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# libtiff -> zstd[version='>=1.4'] -> libstdcxx-ng[version='>=7.5.0|>=9.3.0']
# fsspec -> python[version='>=3.5'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# pyzmq -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.5.0']
# prompt-toolkit -> python[version='>=3.6'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# binutils_linux-64 -> binutils_impl_linux-64=2.33.1 -> libstdcxx-ng[version='>=7.3.0']
# python~=3.7 -> libffi[version='>=3.2.1,<4.0a0'] -> libstdcxx-ng=7.2.0
# cairo -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=7.5.0|>=9.4.0']
# backports -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# opencv==3.4.9 -> libopencv==3.4.9=py37_2 -> libstdcxx-ng[version='>=7.3.0']
# ipython -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# lz4-c -> libstdcxx-ng[version='>=7.3.0|>=9.3.0|>=7.5.0']
# python~=3.7 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# dask-core -> python[version='>=3.6'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# tenacity -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pyshp -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# graphite2 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cytoolz -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# xorg-libxpm -> gettext[version='>=0.19.8.1,<1.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# tensorflow==1.14.0 -> python=3.6 -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# scipy -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# ffmpeg -> gmp[version='>=6.1.2'] -> libstdcxx-ng[version='>=7.5.0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# gxx_impl_linux-64 -> gcc_impl_linux-64==7.3.0=habb00fd_1 -> libstdcxx-ng[version='>=4.9|>=5.4.0|>=7.2.0|>=7.3.0|>=9.3.0|>=8.4.0|>=7.5.0']
# locket -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# libclang -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# ibm_db==3.0.4 -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.4.0']
# libprotobuf -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# dataclasses -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
# harfbuzz -> icu[version='>=58.2,<59.0a0'] -> libstdcxx-ng=7.2.0
# libglib -> gettext[version='>=0.19.8.1,<1.0a0'] -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0']
# markdown -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.4.0|>=7.5.0']
# expat -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0|>=9.3.0']
# pyzmq -> libstdcxx-ng[version='>=7.3.0|>=9.4.0']
# debugpy -> libstdcxx-ng[version='>=7.5.0|>=9.4.0']
# wheel -> python -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0|>=9.4.0']
#
# Package libprotobuf conflicts for:
# libopencv -> libprotobuf[version='>=3.5.2,<3.6.0a0']
# py-opencv -> libopencv==3.4.2=he6673a0_0 -> libprotobuf[version='>=3.5.2,<3.6.0a0']
# grpcio -> protobuf[version='>=3.5.0'] -> libprotobuf[version='3.10.1.*|3.11.2.*|3.11.3.*|3.11.4.*|3.12.3.*|3.12.4.*|3.13.0.*|3.13.0.1.*|>=3.13.0.1,<3.14.0a0|>=3.13.0,<3.14.0a0|>=3.12.4,<3.13.0a0|>=3.12.3,<3.13.0a0|>=3.11.4,<3.12.0a0|>=3.11.3,<3.12.0a0|>=3.11.2,<3.12.0a0|>=3.10.1,<3.11.0a0|3.9.2.*|>=3.9.2,<3.10.0a0|3.8.0.*|>=3.8.0,<3.9.0a0|>=3.7.1,<3.8.0a0|>=3.6.1,<3.6.2.0a0|>=3.6.0,<3.6.1.0a0|>=3.5.2,<3.6.0a0|>=3.5.1,<3.6.0a0|3.19.1.*|>=3.19.1,<3.20.0a0|3.17.2.*|>=3.17.2,<3.18.0a0|3.14.0.*|>=3.14.0,<3.15.0a0']
# tensorflow-base -> libprotobuf[version='>=3.14.0,<3.15.0a0']
# tensorflow-base -> protobuf[version='>=3.8.0'] -> libprotobuf[version='3.10.1.*|3.11.2.*|3.11.3.*|3.11.4.*|3.12.3.*|3.12.4.*|3.13.0.*|3.13.0.1.*|>=3.13.0.1,<3.14.0a0|>=3.13.0,<3.14.0a0|>=3.12.4,<3.13.0a0|>=3.12.3,<3.13.0a0|>=3.11.4,<3.12.0a0|>=3.11.3,<3.12.0a0|>=3.11.2,<3.12.0a0|>=3.10.1,<3.11.0a0|3.9.2.*|>=3.9.2,<3.10.0a0|3.8.0.*|>=3.8.0,<3.9.0a0|3.19.1.*|>=3.19.1,<3.20.0a0|3.17.2.*|>=3.17.2,<3.18.0a0|3.14.0.*|>=3.7.1,<3.8.0a0|>=3.6.1,<3.6.2.0a0|>=3.6.0,<3.6.1.0a0|>=3.5.2,<3.6.0a0|>=3.5.1,<3.6.0a0|>=3.4.1,<3.5.0a0']
# imutils==0.5.4 -> numpy -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.0|>=2018.0.1|>=2018.0.2|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.3,<2020.0a0|>=2019.4,<2020.0a0|>=2021.4.0,<2022.0a0|>=2021.3.0,<2022.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.3,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.2,<2019.0a0|>=2018.0.1,<2019.0a0']
# pytorch==1.5.0 -> mkl-service[version='>=2,<3.0a0'] -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.0|>=2018.0.1|>=2018.0.2|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.3,<2020.0a0|>=2021.4.0,<2022.0a0|>=2021.2.0,<2022.0a0|>=2019.3,<2021.0a0|>=2021.3.0,<2022.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.2,<2019.0a0|>=2018.0.1,<2019.0a0']
# pycocotools==2.0.2 -> numpy[version='>=1.18.5,<2.0a0'] -> mkl[version='>=2019.4,<2020.0a0|>=2021.4.0,<2022.0a0|>=2021.3.0,<2022.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0']
#
# Package zlib conflicts for:
# idna -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# dask-core -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# flask -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# basemap==1.2.0 -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# certifi -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# parso -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# glib -> zlib[version='>=1.2.11,<1.3.0a0']
# libnghttp2 -> zlib[version='>=1.2.11,<1.3.0a0']
# traitlets -> python[version='>=3.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# packaging -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# tensorboard -> grpcio[version='>=1.24.3'] -> zlib[version='>=1.2.11,<1.3.0a0']
# decorator -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pycparser -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# gast -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pyproj -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pytz -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# tensorflow-estimator -> python[version='>=3'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tifffile -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# nest-asyncio -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# importlib-metadata -> python[version='>=3'] -> zlib[version='>=1.2.11,<1.3.0a0']
# jinja2 -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# pyparsing -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# imutils==0.5.4 -> opencv -> zlib[version='>=1.2.11,<1.3.0a0']
# pygments -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0']
# libcurl -> zlib[version='>=1.2.11,<1.3.0a0']
# xlrd==1.2.0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# grpcio -> zlib[version='>=1.2.11,<1.3.0a0']
# seaborn -> matplotlib[version='>=2.1.2'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libssh2 -> zlib[version='>=1.2.11,<1.3.0a0']
# libllvm11 -> zlib[version='>=1.2.11,<1.3.0a0']
# ibm_db==3.0.4 -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# gstreamer -> glib[version='>=2.56.1,<2.57.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# wcwidth -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# brotlipy -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# py-opencv -> libopencv==3.4.2=hb342d67_1 -> zlib[version='>=1.2.11,<1.3.0a0']
# pycocotools==2.0.2 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# plotly -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# opencv==3.4.9 -> libopencv==3.4.9=py37_2 -> zlib[version='>=1.2.11,<1.3.0a0']
# tk -> zlib[version='>=1.2.11,<1.3.0a0']
# pywavelets -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0']
# tesseract==4.1.1 -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter_client -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# absl-py -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pip -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0']
# mysql-libs -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0']
# cython -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# gst-plugins-base -> zlib[version='>=1.2.11,<1.3.0a0']
# gettext -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib-inline -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# brotli-python -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# google-pasta -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# werkzeug -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# krb5 -> tk[version='>=8.6.8,<8.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# dataclasses -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# charset-normalizer -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# kiwisolver -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# partd -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libclang -> libllvm10[version='>=10.0.1,<10.1.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# entrypoints -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ffmpeg -> zlib[version='>=1.2.11,<1.3.0a0']
# cycler -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# ninja -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pytorch==1.5.0 -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libwebp -> libpng[version='>=1.6.37,<1.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# flask-compress -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# imagecodecs-lite -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# scikit-image==0.17.2 -> pillow[version='>=4.3.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# openjpeg -> zlib[version='>=1.2.11,<1.3.0a0']
# fontconfig -> freetype[version='>=2.9.1,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# fonttools -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# hdf5 -> zlib[version='1.2.*|>=1.2.11,<1.3.0a0']
# dbus -> glib -> zlib[version='>=1.2.11,<1.3.0a0']
# imageio -> pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# tensorflow-base -> zlib[version='>=1.2.11,<1.3.0a0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backcall -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0']
# dash -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# python~=3.7 -> zlib[version='>=1.2.11,<1.3.0a0']
# ptyprocess -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libxkbcommon -> libxml2[version='>=2.9.10,<2.10.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# harfbuzz -> cairo[version='>=1.14.12,<2.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# protobuf -> libprotobuf=3.13.0.1 -> zlib[version='>=1.2.11,<1.3.0a0']
# pyshp -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# libopencv -> hdf5[version='>=1.8.18,<1.8.19.0a0'] -> zlib=1.2
# h5py -> hdf5[version='>=1.10.6,<1.10.7.0a0'] -> zlib[version='1.2.*|>=1.2.11,<1.3.0a0']
# matplotlib-base -> freetype[version='>=2.10.2,<3.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cloudpickle -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# click -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# munkres -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# scipy -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# setuptools -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tenacity -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tensorflow==1.14.0 -> zlib[version='>=1.2.11,<1.3.0a0']
# openh264 -> zlib[version='>=1.2.11,<1.3.0a0']
# libprotobuf -> zlib[version='>=1.2.11,<1.3.0a0']
# markupsafe -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cytoolz -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyzmq -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# markdown -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pyyaml -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# networkx -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# toolz -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# typing_extensions -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# locket -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pexpect -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libopencv -> zlib[version='>=1.2.11,<1.3.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backports.functools_lru_cache -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# jedi -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# keras-preprocessing -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# graphviz==2.40.1 -> zlib[version='>=1.2.11,<1.3.0a0']
# pango -> zlib[version='>=1.2.11,<1.3.0a0']
# argcomplete -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0']
# qt -> zlib[version='>=1.2.11,<1.3.0a0']
# cffi -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# unicodedata2 -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# libarchive -> zlib[version='>=1.2.11,<1.3.0a0']
# pyopenssl -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# itsdangerous -> python[version='>=2.7,<2.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# requests -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter-dash==0.4.0 -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# leptonica -> zlib[version='>=1.2.11,<1.3.0a0']
# wheel -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# ipython -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# retrying -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tornado -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# tqdm==4.60.0 -> python[version='>=2.7'] -> zlib[version='>=1.2.11,<1.3.0a0']
# astor -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# keras-applications -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# libpq -> zlib[version='>=1.2.11,<1.3.0a0']
# six -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# fsspec -> python[version='>=3.5'] -> zlib[version='>=1.2.11,<1.3.0a0']
# maven==3.6.0 -> openjdk -> zlib[version='>=1.2.11,<1.3.0a0']
# wrapt -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# backports -> python -> zlib[version='>=1.2.11,<1.3.0a0']
# cryptography -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pickleshare -> python[version='>=3.7,<3.8.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# debugpy -> python[version='>=3.10,<3.11.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# zipp -> python[version='>=3.6'] -> zlib[version='>=1.2.11,<1.3.0a0']
# termcolor -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# nss -> zlib[version='>=1.2.11,<1.3.0a0']
# ipykernel -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# cairo -> zlib[version='>=1.2.11,<1.3.0a0']
# jupyter_core -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# pandas -> python[version='>=3.6,<3.7.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# urllib3 -> python[version='<4.0'] -> zlib[version='>=1.2.11,<1.3.0a0']
# python_abi -> python=3.7 -> zlib[version='>=1.2.11,<1.3.0a0']
# ansi2html -> python[version='>=3.8,<3.9.0a0'] -> zlib[version='>=1.2.11,<1.3.0a0']
#
# Package tzdata conflicts for:
# retrying -> python -> tzdata
# tqdm==4.60.0 -> python[version='>=2.7'] -> tzdata
# six -> python -> tzdata
# fsspec -> python[version='>=3.5'] -> tzdata
# backports -> python -> tzdata
# ipython -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyparsing -> python -> tzdata
# termcolor -> python -> tzdata
# munkres -> python -> tzdata
# scipy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# kiwisolver -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# argcomplete -> python -> tzdata
# packaging -> python -> tzdata
# imageio -> python[version='>=3'] -> tzdata
# pip -> python[version='>=3.6'] -> tzdata
# decorator -> python -> tzdata
# pycparser -> python -> tzdata
# gast -> python -> tzdata
# pyzmq -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# pytz -> python -> tzdata
# backports.functools_lru_cache -> python -> tzdata
# keras-preprocessing -> python -> tzdata
# pyshp -> python -> tzdata
# jinja2 -> python -> tzdata
# pickleshare -> python[version='>=3'] -> tzdata
# dataclasses -> python[version='>=3.7'] -> tzdata
# markupsafe -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# pywavelets -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# itsdangerous -> python -> tzdata
# ptyprocess -> python -> tzdata
# ipykernel -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# keras-applications -> python -> tzdata
# ninja -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# unicodedata2 -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# cycler -> python[version='>=3.6'] -> tzdata
# plotly -> python -> tzdata
# zipp -> python[version='>=3.6'] -> tzdata
# glib -> python= -> tzdata
# python~=3.7 -> tzdata
# jupyter_client -> python[version='>=3.5'] -> tzdata
# protobuf -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# idna -> python -> tzdata
# flask -> python -> tzdata
# flask-compress -> python -> tzdata
# scikit-image==0.17.2 -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# pyyaml -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# traitlets -> python[version='>=3.7'] -> tzdata
# tornado -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# pygments -> python[version='>=3.5'] -> tzdata
# fonttools -> python -> tzdata
# seaborn -> python[version='>=3.6'] -> tzdata
# tensorboard -> python[version='>=3.5'] -> tzdata
# pyopenssl -> python -> tzdata
# astor -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# markdown -> python[version='>=3.6'] -> tzdata
# matplotlib-inline -> python[version='>=3.6'] -> tzdata
# google-pasta -> python -> tzdata
# werkzeug -> python -> tzdata
# dash -> python -> tzdata
# ansi2html -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# pexpect -> python -> tzdata
# prompt-toolkit -> python[version='>=3.6'] -> tzdata
# entrypoints -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# matplotlib-base -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# tenacity -> python -> tzdata
# olefile -> python -> tzdata
# locket -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# python-dateutil -> python -> tzdata
# pillow -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# tifffile -> python[version='>=3.6'] -> tzdata
# requests -> python -> tzdata
# numpy -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# wheel -> python -> tzdata
# absl-py -> python[version='>=3.6'] -> tzdata
# cryptography -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# backcall -> python -> tzdata
# nest-asyncio -> python[version='>=3.5'] -> tzdata
# pyproj -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# networkx -> python[version='>=3.6'] -> tzdata
# certifi -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# cytoolz -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# cffi -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# grpcio -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# brotlipy -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# wrapt -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# xlrd==1.2.0 -> python -> tzdata
# partd -> python[version='>=3.5'] -> tzdata
# dask-core -> python[version='>=3.6'] -> tzdata
# parso -> python -> tzdata
# charset-normalizer -> python[version='>=3.5'] -> tzdata
# urllib3 -> python[version='<4.0'] -> tzdata
# cloudpickle -> python[version='>=3.5'] -> tzdata
# jedi -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# toolz -> python[version='>=3.5'] -> tzdata
# debugpy -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# cython -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# pandas -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# jupyter_core -> python -> tzdata
# tensorflow-estimator -> python[version='>=3'] -> tzdata
# tensorflow-base -> python[version='>=3.9,<3.10.0a0'] -> tzdata
# typing_extensions -> python[version='>=3.5'] -> tzdata
# importlib-metadata -> python[version='>=3'] -> tzdata
# h5py -> python[version='>=3.10,<3.11.0a0'] -> tzdata
# jupyter-dash==0.4.0 -> python[version='>=3.5'] -> tzdata
# wcwidth -> python -> tzdata
# ...
# libclang -> libllvm11[version='>=11.1.0,<11.2.0a0']
#
# Package more-itertools conflicts for:
# zipp -> jaraco.itertools -> more-itertools[version='>=4.0.0']
# zipp -> more-itertools
#
# Package kernel-headers_linux-64 conflicts for:
# gxx_impl_linux-64 -> sysroot_linux-64 -> kernel-headers_linux-64==3.10.0=h57e8cba_10
# binutils_linux-64 -> sysroot_linux-64 -> kernel-headers_linux-64==3.10.0=h57e8cba_10
# gcc_impl_linux-64 -> sysroot_linux-64 -> kernel-headers_linux-64==3.10.0=h57e8cba_10
# binutils_impl_linux-64 -> sysroot_linux-64 -> kernel-headers_linux-64==3.10.0=h57e8cba_10
# gcc_linux-64 -> sysroot_linux-64 -> kernel-headers_linux-64==3.10.0=h57e8cba_10
#
# Package libvpx conflicts for:
# libopencv -> ffmpeg[version='>=4.0,<4.1.0a0'] -> libvpx[version='>=1.6.1,<1.7.0a0|>=1.7.0,<1.8.0a0']
# ffmpeg -> libvpx[version='>=1.6.1,<1.7.0a0|>=1.7.0,<1.8.0a0']
#
# Package nspr conflicts for:
# qt -> nspr[version='>=4.29,<5.0a0']
# nss -> nspr[version='>=4.22,<5.0a0|>=4.33,<5|>=4.33,<5.0a0|>=4.32,<5.0a0|>=4.27']
# libopencv -> qt=5.12 -> nspr[version='>=4.29,<5.0a0']
# qt -> nss[version='>=3.61,<4.0a0'] -> nspr[version='>=4.32,<5.0a0|>=4.33,<5|>=4.33,<5.0a0']
#
# Package zeromq conflicts for:
# pyzmq -> zeromq[version='4.2.*|>=4.2.3,<4.3|>=4.2.5,<4.2.6.0a0|>=4.3.1,<4.4.0a0|>=4.3.2,<4.4.0a0|>=4.3.4,<4.4.0a0|>=4.3.3,<4.4.0a0']
# jupyter_client -> pyzmq[version='>=13'] -> zeromq[version='4.2.*|>=4.2.3,<4.3|>=4.2.5,<4.2.6.0a0|>=4.3.1,<4.4.0a0|>=4.3.2,<4.4.0a0|>=4.3.4,<4.4.0a0|>=4.3.3,<4.4.0a0']
#
# Package flask-compress conflicts for:
# dash -> flask-compress
# jupyter-dash==0.4.0 -> dash -> flask-compress
#
# Package backports.functools_lru_cache conflicts for:
# seaborn -> matplotlib[version='>=2.1.2'] -> backports.functools_lru_cache
# wcwidth -> backports.functools_lru_cache
# basemap==1.2.0 -> matplotlib[version='>=1.0.0'] -> backports.functools_lru_cache
# prompt-toolkit -> wcwidth -> backports.functools_lru_cache
#
# Package asn1crypto conflicts for:
# pyopenssl -> cryptography[version='>=2.8'] -> asn1crypto[version='>=0.21.0']
# urllib3 -> cryptography[version='>=1.3.4'] -> asn1crypto[version='>=0.21.0']
# cryptography -> asn1crypto[version='>=0.21.0']
#
# Package freeglut conflicts for:
# jasper -> freeglut[version='>=2.8.1,<3.0a0|>=3.0.0,<4.0a0']
# libopencv -> jasper[version='>=2.0.14,<3.0a0'] -> freeglut[version='>=2.8.1,<3.0a0|>=3.0.0,<4.0a0']
#
# Package libbrotlienc conflicts for:
# brotli -> libbrotlienc==1.0.9=h7f98852_6
# fonttools -> brotli -> libbrotlienc==1.0.9=h7f98852_6
# brotli-bin -> libbrotlienc==1.0.9=h7f98852_6
#
# Package jedi conflicts for:
# ipython -> jedi[version='>=0.10,<0.18|>=0.10|>=0.16|>=0.16,<1.0']
# ipykernel -> ipython[version='>=5.0'] -> jedi[version='>=0.10,<0.18|>=0.10|>=0.16|>=0.16,<1.0']
# jupyter-dash==0.4.0 -> ipython -> jedi[version='>=0.10,<0.18|>=0.10|>=0.16|>=0.16,<1.0']
#
# Package fribidi conflicts for:
# graphviz==2.40.1 -> fribidi[version='>=1.0.4,<2.0a0']
# graphviz==2.40.1 -> pango[version='>=1.42.1,<2.0a0'] -> fribidi[version='>=1.0.10,<2.0a0|>=1.0.2,<2.0a0|>=1.0.5,<2.0a0|>=1.0.9,<2.0a0']
# pango -> fribidi[version='>=1.0.10,<2.0a0|>=1.0.2,<2.0a0|>=1.0.4,<2.0a0|>=1.0.5,<2.0a0|>=1.0.9,<2.0a0']
#
# Package brotli-bin conflicts for:
# brotli -> brotli-bin==1.0.9=h7f98852_6
# fonttools -> brotli -> brotli-bin==1.0.9=h7f98852_6
#
# Package gnutls conflicts for:
# ffmpeg -> gnutls[version='>=3.6.5,<3.7.0a0']
# libopencv -> ffmpeg[version='>=4.1.3,<4.2.0a0'] -> gnutls[version='>=3.6.5,<3.7.0a0']
#
# Package scandir conflicts for:
# importlib_metadata -> pathlib2 -> scandir
# pickleshare -> pathlib2 -> scandir
# ipython -> pathlib2 -> scandir
#
# Package astor conflicts for:
# tensorflow==1.14.0 -> tensorflow-base==1.14.0=gpu_py36he45bfe2_0 -> astor[version='>=0.6.0']
# tensorflow-estimator -> astor[version='>=0.6.0']
# tensorflow-estimator -> tensorflow-base[version='>=2.1.0,<2.2.0a0'] -> astor[version='>=0.6.2|>=0.6.2,<1.0a0']
# tensorflow-base -> astor[version='>=0.6.0|>=0.6.2|>=0.6.2,<1.0a0']
#
# Package pycparser conflicts for:
# brotlipy -> cffi[version='>=1.0.0'] -> pycparser
# pytorch==1.5.0 -> cffi -> pycparser
# cffi -> pycparser
# cryptography -> cffi[version='!=1.11.3,>=1.8'] -> pycparser
#
# Package xorg-renderproto conflicts for:
# cairo -> xorg-libxrender -> xorg-renderproto
# graphviz==2.40.1 -> xorg-libxrender -> xorg-renderproto
# xorg-libxrender -> xorg-renderproto
#
# Package entrypoints conflicts for:
# jupyter_client -> entrypoints
# ipykernel -> jupyter_client -> entrypoints
#
# Package x264 conflicts for:
# libopencv -> ffmpeg[version='>=4.1.3,<4.2.0a0'] -> x264[version='>=1!152.20180806,<1!153']
# ffmpeg -> x264[version='>=1!152.20180806,<1!153|>=1!157.20191217,<1!158']
#
# Package markupsafe conflicts for:
# flask -> jinja2[version='>=2.10.1'] -> markupsafe[version='>=0.23|>=2.0']
# jinja2 -> markupsafe[version='>=0.23|>=2.0']
#
# Package mkl-include conflicts for:
# mkl-devel -> mkl-include[version='2017.0.4|2018.0.0|2018.0.1|2018.0.2|2018.0.3|2019.0|2019.0|2019.1|2019.3|2019.4|2020.0|2020.1|2020.2|2021.2.0|2021.3.0|2021.4.0|2021.4.0|2022.0.1',build='hf7c01fb_0|1|1|144|243|217|h06a4308_296|h06a4308_117|h8d4b97c_729|h06a4308_640|h06a4308_520|256|166|199|118|117|hc7b2577_4|h15fc484_2']
# blas-devel -> mkl-devel -> mkl-include[version='2017.0.4|2018.0.0|2018.0.1|2018.0.2|2018.0.3|2019.0|2019.0|2019.1|2019.3|2019.4|2020.0|2020.1|2020.2|2021.2.0|2021.3.0|2021.4.0|2021.4.0|2022.0.1',build='hf7c01fb_0|1|1|144|243|217|h06a4308_296|h06a4308_117|h8d4b97c_729|h06a4308_640|h06a4308_520|256|166|199|118|117|hc7b2577_4|h15fc484_2']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.28=0
#   - feature:|@/linux-64::__glibc==2.28=0
#   - alsa-lib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - basemap==1.2.0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - binutils_impl_linux-64 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - blas -> libgfortran-ng -> __glibc[version='>=2.17']
#   - brotli -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - brotli-python -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - brotlipy -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - bzip2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - c-ares -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cairo -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - cffi -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cryptography -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cudatoolkit -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cython -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - cytoolz -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - dbus -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - debugpy -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - expat -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - ffmpeg -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - fontconfig -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - freetype -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - fribidi -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - gcc_impl_linux-64 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - geos -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - gettext -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - giflib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - glib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - gmp -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - gnutls -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - graphite2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - graphviz==2.40.1 -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - grpcio -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - gst-plugins-base -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - gstreamer -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - h5py -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - harfbuzz -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - hdf5 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - ibm_db==3.0.4 -> __glibc[version='>=2.17,<3.0.a0']
#   - ibm_db==3.0.4 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - icu -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - jasper -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - jpeg -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - kiwisolver -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - krb5 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - lame -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - lcms2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - leptonica -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libarchive -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libclang -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libcurl -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libedit -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libev -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libevent -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libffi -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libgfortran-ng -> __glibc[version='>=2.17']
#   - libiconv -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - libllvm11 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libnghttp2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libogg -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libopencv -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libopus -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libpng -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libpq -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libprotobuf -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libsodium -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libssh2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtiff -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libtool -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - libvorbis -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libwebp -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libxcb -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libxkbcommon -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libzlib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - lz4-c -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - lzo -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - markupsafe -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib-base -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - mysql-libs -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ncurses -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - nettle==3.6 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - ninja -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - nodejs==10.15.3 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - nspr -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - nss -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - numpy -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - openh264 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - openjpeg -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - openssl -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pandas -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pango -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pcre -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pillow -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pixman -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - proj4==5.2.0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - protobuf -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pthread-stubs -> libgcc-ng[version='>=7.2.0'] -> __glibc[version='>=2.17']
#   - py-opencv -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pyproj -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - python~=3.7 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pytorch==1.5.0 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pywavelets -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pyyaml -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - pyzmq -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - qt -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - readline -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - scikit-image==0.17.2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - scipy -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - sqlite -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tbb -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tensorboard -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tensorflow-base -> libgcc-ng[version='>=5.4.0'] -> __glibc[version='>=2.17']
#   - tensorflow==1.14.0 -> libgcc-ng[version='>=5.4.0'] -> __glibc[version='>=2.17']
#   - tesseract==4.1.1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tifffile -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tk -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tornado -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - unicodedata2 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - wrapt -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - x264 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xorg-kbproto -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libice -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libsm -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libx11 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxau -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxdmcp -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxext -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxpm -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxrender -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-libxt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-renderproto -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-xextproto -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xorg-xproto -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - xz -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zeromq -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zlib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.28

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Let's look at the day of the week people get the loan

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins = np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that people who get the loan at the end of the week don't pay it off, so let's use Feature binarization to set a threshold value less than day 4

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Let's look at gender:

# %%
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# 0       PAIDOFF        0.731293
#         COLLECTION     0.268707
# 1       PAIDOFF        0.865385
#         COLLECTION     0.134615
# Name: loan_status, dtype: float64

# %% [markdown]
# 86 % of female pay there loans while only 73 % of males pay there loan

# %% [markdown]
# Let's convert male to 0 and female to 1:

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %% [markdown]
# ## One Hot Encoding
#
# #### How about education?

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %% [markdown]
# #### Features before One Hot Encoding

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %% [markdown]
# #### Use one hot encoding technique to conver categorical varables to binary variables and append them to the feature Data Frame

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# Let's define feature sets, X:

# %%
X = Feature
X[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %% [markdown]
# What are our lables?

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split)

# %%
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.
# array([[ 0.51578458,  0.92071769,  2.33152555, -0.42056004, -1.20577805,
#         -0.38170062,  1.13639374, -0.86968108],
#        [ 0.51578458,  0.92071769,  0.34170148,  2.37778177, -1.20577805,
#          2.61985426, -0.87997669, -0.86968108],
#        [ 0.51578458, -0.95911111, -0.65321055, -0.42056004, -1.20577805,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.48739188,  2.37778177,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.3215732 , -0.42056004,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679]])

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the test set to report the accuracy of the model
# You should use the following algorithm:
#
# *   K Nearest Neighbor(KNN)
# *   Decision Tree
# *   Support Vector Machine
# *   Logistic Regression
#
# \__ Notice:\__
#
# *   You can go above and change the pre-processing, feature selection, feature-extraction, and so on, to make a better model.
# *   You should use either scikit-learn, Scipy or Numpy libraries for developing the classification algorithms.
# *   You should include the code of the algorithm in the following cells.

# %% [markdown]
# # K Nearest Neighbor(KNN)
#
# Notice: You should find the best k to build the model with the best accuracy.\
# **warning:** You should not use the **loan_test.csv** for finding the best k, however, you can split your train_loan.csv into train and test to find the best **k**.

# %%
from sklearn.model_selection import train_test_split
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 4
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_trainset,y_trainset)
yhat = neigh.predict(X_testset)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/neighbors/base.py:907: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self._y = np.empty(y.shape, dtype=np.int)

# %%
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_trainset, neigh.predict(X_trainset)))
print("Test set Accuracy: ", metrics.accuracy_score(y_testset, yhat))
# Out:
# Train set Accuracy:  0.859504132231405
# Test set Accuracy:  0.7019230769230769

# %% [markdown]
# # Decision Tree

# %%
from sklearn.model_selection import train_test_split
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
from sklearn.tree import DecisionTreeClassifier
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
# it shows the default parameters
drugTree.fit(X_trainset,y_trainset)
predTree = drugTree.predict(X_testset)
drugTree.predict(X_testset)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/tree/tree.py:149: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_encoded = np.zeros(y.shape, dtype=np.int)
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'COLLECTION', 'PAIDOFF', 'COLLECTION', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'COLLECTION',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'COLLECTION', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'COLLECTION', 'COLLECTION',
#        'COLLECTION', 'COLLECTION', 'COLLECTION', 'PAIDOFF', 'COLLECTION',
#        'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'PAIDOFF', 'COLLECTION', 'COLLECTION', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'PAIDOFF', 'COLLECTION',
#        'COLLECTION', 'COLLECTION', 'COLLECTION', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF',
#        'PAIDOFF', 'PAIDOFF', 'COLLECTION', 'COLLECTION', 'PAIDOFF',
#        'PAIDOFF', 'COLLECTION'], dtype=object)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.6538461538461539

# %% [markdown]
# # Support Vector Machine

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (276, 8) (276,)
# Test set: (70, 8) (70,)

# %%
from sklearn import svm
from sklearn.metrics import classification_report, confusion_matrix
import itertools
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train) 
yhat = clf.predict(X_test)
yhat [0:5]
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1097: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1480: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:320: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:580: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=None,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# array(['COLLECTION', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, yhat, labels=['COLLECTION', 'PAIDOFF'])
np.set_printoptions(precision=2)

print (classification_report(y_test, yhat))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['label(1)','label(2)'],normalize= False,  title='Confusion matrix')
# Out:
#               precision    recall  f1-score   support
#
#   COLLECTION       0.36      0.27      0.31        15
#      PAIDOFF       0.81      0.87      0.84        55
#
#    micro avg       0.74      0.74      0.74        70
#    macro avg       0.59      0.57      0.57        70
# weighted avg       0.72      0.74      0.73        70
#
# Confusion matrix, without normalization
# [[ 4 11]
#  [ 7 48]]

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
import numpy as np

f1_score(y_test, yhat, average='weighted') 

jaccard_similarity_score(y_test, yhat)
# Out:
# 0.7428571428571429

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
yhat_prob = LR.predict_proba(X_test)
yhat_prob[0:5]
# Out:
# array([[0.5 , 0.5 ],
#        [0.45, 0.55],
#        [0.31, 0.69],
#        [0.34, 0.66],
#        [0.32, 0.68]])

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.7428571428571429

# %%
from sklearn.metrics import log_loss
log_loss(y_test, yhat_prob)
# Out:
# 0.5772287609479654

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %% [markdown]
# First, download and load the test set:

# %%
# !wget -O loan_test.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Out:
# --2022-02-25 04:48:27--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3642 (3.6K) [text/csv]
# Saving to: ‘loan_test.csv’
#
# loan_test.csv       100%[===================>]   3.56K  --.-KB/s    in 0.03s
#
# 2022-02-25 04:48:27 (119 KB/s) - ‘loan_test.csv’ saved [3642/3642]

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('loan_test.csv')
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30       9/8/2016
# 1           5             5     PAIDOFF        300      7       9/9/2016
# 2          21            21     PAIDOFF       1000     30      9/10/2016
# 3          24            24     PAIDOFF       1000     30      9/10/2016
# 4          35            35     PAIDOFF        800     15      9/11/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   50              Bechalor  female
# 1  9/15/2016   35       Master or Above    male
# 2  10/9/2016   43  High School or Below  female
# 3  10/9/2016   26               college    male
# 4  9/25/2016   29              Bechalor    male

# %%
test_df['due_date'] = pd.to_datetime(test_df['due_date'])
test_df['effective_date'] = pd.to_datetime(test_df['effective_date'])
test_df['dayofweek'] = test_df['effective_date'].dt.dayofweek

test_df['weekend'] = test_df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)

test_df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)

test_feature = test_df[['Principal','terms','age','Gender','weekend']]
test_feature = pd.concat([test_feature,pd.get_dummies(test_df['education'])], axis=1)
test_feature.drop(['Master or Above'], axis = 1,inplace=True)

# Testing feature
X_loan_test = test_feature

# Normalizing Test Data
X_loan_test = preprocessing.StandardScaler().fit(X_loan_test).transform(X_loan_test)

# Target result
y_loan_test = test_df['loan_status'].values
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:17: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.

# %%
# Jaccard
from sklearn.metrics import jaccard_similarity_score

# KNN
knn_yhat = neigh.predict(X_loan_test)
jss1 = round(jaccard_similarity_score(y_loan_test, knn_yhat), 2)

# Decision Tree
dt_yhat =drugTree.predict(X_loan_test)
jss2 = round(jaccard_similarity_score(y_loan_test, dt_yhat), 2)

# Support Vector Machine
svc_yhat =clf.predict(X_loan_test)
jss3 = round(jaccard_similarity_score(y_loan_test, svc_yhat), 2)

# Logistic Regression
lr_yhat = LR.predict(X_loan_test)
jss4 = round(jaccard_similarity_score(y_loan_test, lr_yhat), 2)

jss_list = [jss1, jss2, jss3, jss4]
jss_list
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/base.py:283: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   indices = (scores > 0).astype(np.int)
# [0.69, 0.78, 0.8, 0.74]

# %%
# F1_score
from sklearn.metrics import f1_score

# KNN
knn_yhat = neigh.predict(X_loan_test)
f1 = round(f1_score(y_loan_test, knn_yhat, average = 'weighted'), 2)

# Decision Tree
dt_yhat =drugTree.predict(X_loan_test)
f2 = round(f1_score(y_loan_test, dt_yhat, average = 'weighted'), 2)

# Support Vector Machine
svc_yhat = clf.predict(X_loan_test)
f3 = round(f1_score(y_loan_test, svc_yhat, average = 'weighted'), 2)

# Logistic Regression
lr_yhat = LR.predict(X_loan_test)
f4 = round(f1_score(y_loan_test, lr_yhat, average = 'weighted'), 2)

f1_list = [f1, f2, f3, f4]
f1_list
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/base.py:283: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   indices = (scores > 0).astype(np.int)
# [0.69, 0.78, 0.76, 0.66]

# %%
# log loss
from sklearn.metrics import log_loss

# Logistic Regression
lr_prob = LR.predict_proba(X_loan_test)
ll_list = ['NA','NA','NA', round(log_loss(y_loan_test, lr_prob), 2)]
ll_list
# Out:
# ['NA', 'NA', 'NA', 0.57]

# %%
columns = ['KNN', 'Decision Tree', 'SVM', 'Logistic Regression']
index = ['Jaccard', 'F1-score', 'Logloss']
accuracy_df = pd.DataFrame([jss_list, f1_list, ll_list], index = index, columns = columns)

# %%
accuracy_df1 = accuracy_df.transpose()
accuracy_df1.columns.name = 'Algorithm'
accuracy_df1
# Out:
# Algorithm           Jaccard F1-score Logloss
# KNN                    0.69     0.69      NA
# Decision Tree          0.78     0.78      NA
# SVM                     0.8     0.76      NA
# Logistic Regression    0.74     0.66    0.57

# %% [markdown]
# # Report
#
# You should be able to report the accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Jaccard | F1-score | LogLoss |
# | ------------------ | ------- | -------- | ------- |
# | KNN                | ?       | ?        | NA      |
# | Decision Tree      | ?       | ?        | NA      |
# | SVM                | ?       | ?        | NA      |
# | LogisticRegression | ?       | ?        | ?       |

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: <a href="http://cocl.us/ML0101EN-SPSSModeler?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2021-01-01">SPSS Modeler</a>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://cocl.us/ML0101EN_DSX?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2021-01-01">Watson Studio</a>
#
# <h3>Thanks for completing this lesson!</h3>
#
# <h4>Author:  <a href="https://ca.linkedin.com/in/saeedaghabozorgi?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2021-01-01?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2021-01-01">Saeed Aghabozorgi</a></h4>
# <p><a href="https://ca.linkedin.com/in/saeedaghabozorgi">Saeed Aghabozorgi</a>, PhD is a Data Scientist in IBM with a track record of developing enterprise level applications that substantially increases clients’ ability to turn data into actionable knowledge. He is a researcher in data mining field and expert in developing advanced analytic methods like machine learning and statistical modelling on large datasets.</p>
#
# <hr>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description                                                             |
# | ----------------- | ------- | ------------- | ------------------------------------------------------------------------------ |
# | 2020-10-27        | 2.1     | Lakshmi Holla | Made changes in import statement due to updates in version of  sklearn library |
# | 2020-08-27        | 2.0     | Malika Singla | Added lab to GitLab                                                            |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <p>
